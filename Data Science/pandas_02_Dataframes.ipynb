# %% [markdown]
# Data Frames

# %%
import numpy as np
import pandas as pd

# %%
#value_count()(series+dataframes)
marks = pd.DataFrame([
    ['Roshan',100,80,10],
    ['Nitin',90,70,7],
    ['Nikhil',120,100,94],
    ['Rohit',80,70,14],
    ['Rahul',80,70,14]
],columns=['Name','iq','marks','package'])
marks.set_index('Name',inplace=True)
marks
# Out:
#          iq  marks  package
# Name
# Roshan  100     80       10
# Nitin    90     70        7
# Nikhil  120    100       94
# Rohit    80     70       14
# Rahul    80     70       14

# %%
marks.value_counts()
marks['iq'].value_counts()
# Out:
# iq
# 80     2
# 100    1
# 90     1
# 120    1
# Name: count, dtype: int64

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Attributes

# %%
#shape
movies.shape
# Out:
# (1629, 18)

# %%
#dtype
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
#index
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
#coloums
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
ipl.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
#head and tail
ipl.head(2)
ipl.tail(2)
ipl.sample(2)
# Out:
#           ID       City        Date   Season MatchNumber  \
# 182  1216504        NaN  2020-09-30  2020/21          12
# 533   729315  Abu Dhabi  2014-04-29     2014          19
#
#                      Team1             Team2  \
# 182  Kolkata Knight Riders  Rajasthan Royals
# 533  Kolkata Knight Riders  Rajasthan Royals
#
#                                    Venue        TossWinner TossDecision  \
# 182  Dubai International Cricket Stadium  Rajasthan Royals        field
# 533                 Sheikh Zayed Stadium  Rajasthan Royals          bat
#
#     SuperOver            WinningTeam      WonBy  Margin method  \
# 182         N  Kolkata Knight Riders       Runs    37.0    NaN
# 533         Y       Rajasthan Royals  SuperOver     NaN    NaN
#
#     Player_of_Match                                       Team1Players  \
# 182     Shivam Mavi  ['Shubman Gill', 'SP Narine', 'N Rana', 'AD Ru...
# 533     JP Faulkner  ['G Gambhir', 'MS Bisla', 'JH Kallis', 'MK Pan...
#
# ...

# %%
#info
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
#isnull
ipl.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
#duplicated
movies.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627    False
# 1628    False
# Length: 1629, dtype: bool

# %%
#rename
marks.rename(columns={'package':'lpa'})
# Out:
#          iq  marks  lpa
# Name
# Roshan  100     80   10
# Nitin    90     70    7
# Nikhil  120    100   94
# Rohit    80     70   14
# Rahul    80     70   14

# %% [markdown]
# Mathematical Function

# %%
#sum
marks.sum()
# Out:
# iq         470
# marks      390
# package    139
# dtype: int64

# %%
marks.mean()
marks.mode()
# Out:
#    iq  marks  package
# 0  80     70       14

# %% [markdown]
# Selecting row and columns

# %%
#single col
movies['title_x']# this is a series
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
#mul_col
movies[['title_x','actors','year_of_release']]
# Out:
#                                    title_x  \
# 0                 Uri: The Surgical Strike
# 1                            Battalion 609
# 2     The Accidental Prime Minister (film)
# 3                          Why Cheat India
# 4                          Evening Shadows
# ...                                    ...
# 1624                 Tera Mera Saath Rahen
# 1625                  Yeh Zindagi Ka Safar
# 1626                       Sabse Bada Sukh
# 1627                                 Daaka
# 1628                              Humsafar
#
#                                                  actors  year_of_release
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...             2019
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...             2019
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...             2019
# 3     Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...             2019
# 4     Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...             2018
# ...

# %% [markdown]
# Getting Rows

# %%
#Single Row
#iloc
movies.iloc[9]
# Out:
# title_x                                              Thackeray (film)
# imdb_id                                                     tt7777196
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link              https://en.wikipedia.org/wiki/Thackeray_(film)
# title_y                                                     Thackeray
# original_title                                              Thackeray
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           120
# genres                                                Biography|Drama
# imdb_rating                                                       5.1
# imdb_votes                                                       2301
# story               Balasaheb Thackrey works as a cartoonist for a...
# ...

# %%
#single row
#loc
marks.loc['Nikhil']
# Out:
# iq         120
# marks      100
# package     94
# Name: Nikhil, dtype: int64

# %%
#multiple
marks.loc['Roshan':'Nikhil']#last one is included
# Out:
#          iq  marks  package
# Name
# Roshan  100     80       10
# Nitin    90     70        7
# Nikhil  120    100       94

# %%
#multiple row
movies.iloc[1:10]#Can use fancy indexing
# Out:
#                                 title_x    imdb_id  \
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
# 5                           Soni (film)  tt6078866
# 6                         Fraud Saiyaan  tt5013008
# 7                            Bombairiya  tt4971258
# 8      Manikarnika: The Queen of Jhansi  tt6903440
# 9                      Thackeray (film)  tt7777196
#
#                                          poster_path  \
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
# 6  https://upload.wikimedia.org/wikipedia/en/thum...
# 7  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# Selecting both Row and columns

# %%
movies.iloc[0:3,0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# Filtering the data frames

# %%
ipl.sample(2)
# Out:
#           ID     City        Date Season MatchNumber                Team1  \
# 252  1175357  Kolkata  2019-03-24   2019           2  Sunrisers Hyderabad
# 4    1304116   Mumbai  2022-05-22   2022          70  Sunrisers Hyderabad
#
#                      Team2                     Venue             TossWinner  \
# 252  Kolkata Knight Riders              Eden Gardens  Kolkata Knight Riders
# 4             Punjab Kings  Wankhede Stadium, Mumbai    Sunrisers Hyderabad
#
#     TossDecision SuperOver            WinningTeam    WonBy  Margin method  \
# 252        field         N  Kolkata Knight Riders  Wickets     6.0    NaN
# 4            bat         N           Punjab Kings  Wickets     5.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 252      AD Russell  ['DA Warner', 'JM Bairstow', 'V Shankar', 'YK ...
# 4     Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
# ...

# %%
#find all winnner
mask=ipl['MatchNumber']=='Final'
df=ipl[mask]
df[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
#find no. of superover
ipl[ipl['SuperOver']=='Y'].shape
# Out:
# (14, 20)

# %%
#Toss win Match win
ipl[ipl['TossWinner'] ==ipl['WinningTeam']].shape[0]/ipl.shape[0]
# Out:
# 0.5147368421052632

# %%
ipl[ipl['WinningTeam']=="Royal Challengers Bangalore"]
# Out:
#           ID       City        Date   Season MatchNumber  \
# 2    1312198    Kolkata  2022-05-25     2022  Eliminator
# 7    1304113     Mumbai  2022-05-19     2022          67
# 20   1304100     Mumbai  2022-05-08     2022          54
# 25   1304095       Pune  2022-05-04     2022          49
# 43   1304077     Mumbai  2022-04-19     2022          31
# ..       ...        ...         ...      ...         ...
# 890   392182  Cape Town  2009-04-18     2009           2
# 900   336002  Hyderabad  2008-05-25  2007/08          51
# 904   336029    Chennai  2008-05-21  2007/08          46
# 928   336034  Bangalore  2008-05-03  2007/08          21
# 946   335985     Mumbai  2008-04-20  2007/08           5
#
#                            Team1                        Team2  \
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 7                 Gujarat Titans  Royal Challengers Bangalore
# 20   Royal Challengers Bangalore          Sunrisers Hyderabad
# ...

# %%
team1 = "Royal Challengers Bangalore"
team2 = "Chennai Super Kings"

h2h = ipl[
    ((ipl["Team1"] == team1) & (ipl["Team2"] == team2)) |
    ((ipl["Team1"] == team2) & (ipl["Team2"] == team1))
]

print("Total matches:", h2h.shape[0])
print("\nWins:")
print(h2h["WinningTeam"].value_counts())

h2h[["Season", "MatchNumber", "Team1", "Team2", "WinningTeam"]]
# Out:
# Total matches: 29
#
# Wins:
# WinningTeam
# Chennai Super Kings            19
# Royal Challengers Bangalore    10
# Name: count, dtype: int64
#       Season  MatchNumber                        Team1  \
# 25      2022           49  Royal Challengers Bangalore
# 52      2022           22          Chennai Super Kings
# 99      2021           35  Royal Challengers Bangalore
# 115     2021           19          Chennai Super Kings
# 150  2020/21           44  Royal Challengers Bangalore
# 170  2020/21           25  Royal Challengers Bangalore
# 216     2019           39  Royal Challengers Bangalore
# 253     2019            1  Royal Challengers Bangalore
# 279     2018           35  Royal Challengers Bangalore
# 290     2018           24  Royal Challengers Bangalore
# 434     2015  Qualifier 2          Chennai Super Kings
# 456     2015           37          Chennai Super Kings
# 473     2015           20  Royal Challengers Bangalore
# ...

# %% [markdown]
# ADDING NEW COLUMN

# %%
#completly new col
movies['country']="India"
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#astype
#To change the datatype of col
ipl['ID'].astype('int32')
# Out:
# 0      1312200
# 1      1312199
# 2      1312198
# 3      1312197
# 4      1304116
#         ...
# 945     335986
# 946     335985
# 947     335984
# 948     335983
# 949     335982
# Name: ID, Length: 950, dtype: int32

# %% [markdown]
# Other Functionality of Pandas

# %%
ipl=pd.read_csv('/content/drive/MyDrive/Pandas datasets/ipl-matches.csv')
ipl.sample(2)
# Out:
#           ID        City        Date   Season MatchNumber             Team1  \
# 354  1082608       Delhi  2017-04-17     2017          18  Delhi Daredevils
# 929   336003  Chandigarh  2008-05-03  2007/08          22   Kings XI Punjab
#
#                      Team2                                       Venue  \
# 354  Kolkata Knight Riders                            Feroz Shah Kotla
# 929  Kolkata Knight Riders  Punjab Cricket Association Stadium, Mohali
#
#            TossWinner TossDecision SuperOver            WinningTeam    WonBy  \
# 354  Delhi Daredevils          bat         N  Kolkata Knight Riders  Wickets
# 929   Kings XI Punjab          bat         N        Kings XI Punjab     Runs
#
#      Margin method  Player_of_Match  \
# 354     4.0    NaN  NM Coulter-Nile
# 929     9.0    NaN        IK Pathan
#
#                                           Team1Players  \
# 354  ['SV Samson', 'SW Billings', 'KK Nair', 'SS Iy...
# 929  ['SE Marsh', 'JR Hopes', 'KC Sangakkara', 'Yuv...
#
# ...

# %%
#find the player who have won the potm in knockout matches
ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts().max()
# Out:
# 3

# %%
#Toss decison
ipl['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#How many matches each teams haved played
(ipl['Team1'].value_counts()+ipl['Team2'].value_counts()).sort_values()
# Out:
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Lucknow Super Giants            15
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Punjab Kings                    28
# Gujarat Lions                   30
# Pune Warriors                   46
# Delhi Capitals                  63
# Deccan Chargers                 75
# Sunrisers Hyderabad            152
# Delhi Daredevils               161
# Kings XI Punjab                190
# Rajasthan Royals               192
# Chennai Super Kings            208
# Kolkata Knight Riders          223
# Royal Challengers Bangalore    226
# Mumbai Indians                 231
# Name: count, dtype: int64

# %%
ipl['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Mumbai Indians                 131
# Chennai Super Kings            121
# Kolkata Knight Riders          114
# Royal Challengers Bangalore    109
# Rajasthan Royals                96
# Kings XI Punjab                 88
# Sunrisers Hyderabad             75
# Delhi Daredevils                67
# Delhi Capitals                  36
# Deccan Chargers                 29
# Gujarat Lions                   13
# Punjab Kings                    13
# Gujarat Titans                  12
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Lucknow Super Giants             9
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
#sort_value(series and dataframs)
x=pd.Series([12,3,45,6,78,9])
x.sort_values()
# Out:
# 1     3
# 3     6
# 5     9
# 0    12
# 2    45
# 4    78
# dtype: int64

# %%
movies=pd.read_csv('/content/drive/MyDrive/Pandas datasets/movies.csv')

# %%
movies.head(1)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
#
# ...

# %%
movies.sort_values('title_x').head(3)
# Out:
#                  title_x    imdb_id  \
# 1498  16 December (film)  tt0313844
# 1021         1920 (film)  tt1301698
# 287         1920: London  tt5638500
#
#                                             poster_path  \
# 1498  https://upload.wikimedia.org/wikipedia/en/thum...
# 1021  https://upload.wikimedia.org/wikipedia/en/thum...
# 287   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                              wiki_link      title_y  \
# 1498  https://en.wikipedia.org/wiki/16_December_(film)       16-Dec
# 1021         https://en.wikipedia.org/wiki/1920_(film)         1920
# 287          https://en.wikipedia.org/wiki/1920_London  1920 London
#
#      original_title  is_adult  year_of_release runtime  \
# 1498         16-Dec         0             2002     158
# 1021           1920         0             2008     138
# 287     1920 London         0             2016     120
#
#                       genres  imdb_rating  imdb_votes  \
# ...

# %%
students = pd.DataFrame(
    {
        'name':['nitish','ankit','rupesh',np.nan,'mrityunjay',np.nan,'rishabh',np.nan,'aditya',np.nan],
        'college':['bit','iit','vit',np.nan,np.nan,'vlsi','ssit',np.nan,np.nan,'git'],
        'branch':['eee','it','cse',np.nan,'me','ce','civ','cse','bio',np.nan],
        'cgpa':[6.66,8.25,6.41,np.nan,5.6,9.0,7.4,10,7.4,np.nan],
        'package':[4,5,6,np.nan,6,7,8,9,np.nan,np.nan]

    }
)
students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students.sort_values('name')
#student.sort_values('name',inplace=True) #permanent change in df
# Out:
#          name college branch   cgpa  package
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN

# %%
#sorting in two or more column
movies.sort_values(['year_of_release','title_x'],ascending=[False,True])
# Out:
#                                    title_x     imdb_id  \
# 21                                22 Yards   tt9496212
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 10                                  Amavas   tt8396186
# 46                           Arjun Patiala   tt7881524
# 37                       Article 15 (film)  tt10324144
# ...                                    ...         ...
# 1573                   Yaadein (2001 film)   tt0248617
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1623                              Zubeidaa   tt0255713
#
#                                             poster_path  \
# 21    https://upload.wikimedia.org/wikipedia/en/thum...
# 26    https://upload.wikimedia.org/wikipedia/en/thum...
# 10    https://upload.wikimedia.org/wikipedia/en/thum...
# 46    https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#rank(series)
batsman=pd.read_csv('/content/drive/MyDrive/Pandas datasets/batsman_runs_ipl.csv')
batsman.sample(5)
batsman.sort_values('batsman_run',ascending=False).head(10)
# Out:
#              batter  batsman_run
# 569         V Kohli         6634
# 462        S Dhawan         6244
# 130       DA Warner         5883
# 430       RG Sharma         5881
# 493        SK Raina         5536
# 27   AB de Villiers         5181
# 108        CH Gayle         4997
# 339        MS Dhoni         4978
# 452      RV Uthappa         4954
# 256      KD Karthik         4377

# %%
batsman['Rank']=batsman['batsman_run'].rank(ascending=False)
batsman.sort_values('Rank')
# Out:
#              batter  batsman_run   Rank
# 569         V Kohli         6634    1.0
# 462        S Dhawan         6244    2.0
# 130       DA Warner         5883    3.0
# 430       RG Sharma         5881    4.0
# 493        SK Raina         5536    5.0
# ..              ...          ...    ...
# 570  V Pratap Singh            0  594.0
# 63     Abdur Razzak            0  594.0
# 562          U Kaul            0  594.0
# 65       Akash Deep            0  594.0
# 57           AS Roy            0  594.0
#
# [605 rows x 3 columns]

# %%
#sort_index(series and dataframe)
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
marks = {
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}

marks_series = pd.Series(marks)
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
marks_series.sort_index(ascending=False)
# Out:
# science     89
# maths       67
# hindi      100
# english     57
# dtype: int64

# %%
movies.sort_index(ascending=False).head(3)
# Out:
#               title_x     imdb_id  \
# 1628         Humsafar   tt2403201
# 1627            Daaka  tt10833860
# 1626  Sabse Bada Sukh   tt0069204
#
#                                             poster_path  \
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
#
#                                           wiki_link          title_y  \
# 1628         https://en.wikipedia.org/wiki/Humsafar         Humsafar
# 1627            https://en.wikipedia.org/wiki/Daaka            Daaka
# 1626  https://en.wikipedia.org/wiki/Sabse_Bada_Sukh  Sabse Bada Sukh
#
#        original_title  is_adult  year_of_release runtime         genres  \
# 1628         Humsafar         0             2011      35  Drama|Romance
# 1627            Daaka         0             2019     136         Action
# 1626  Sabse Bada Sukh         0             2018      \N   Comedy|Drama
#
# ...

# %%
#set_index(dataframes) ->inplace
batsman.set_index('batter',inplace=True)
#use inplace to make permanent change

# %%
#reset_index ->inplace
batsman.reset_index(inplace=True)

# %%
batsman
#how to replace existing index without loosing
batsman.reset_index().set_index('Rank')
# Out:
#        index          batter  batsman_run
# Rank
# 166.5      0  A Ashish Reddy          280
# 226.0      1        A Badoni          161
# 535.0      2      A Chandila            4
# 329.0      3        A Chopra           53
# 402.5      4     A Choudhary           25
# ...      ...             ...          ...
# 594.0    600      Yash Dayal            0
# 343.0    601   Yashpal Singh           47
# 547.5    602     Younis Khan            3
# 27.0     603    Yuvraj Singh         2754
# 256.0    604          Z Khan          117
#
# [605 rows x 3 columns]

# %%
#rename
movies.set_index('title_x')
movies.rename(columns={'imdb_id':'imdb'})
# Out:
#                                    title_x        imdb  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#unique(series)
temp=pd.Series([1,1,2,2,4,np.nan])
temp.unique()
# Out:
# array([ 1.,  2.,  4., nan])

# %%
ipl['Season'].unique()
#find no> of unique values
len(ipl['Season'].unique())
# Out:
# 15

# %%
#isnull(series + dataframe)
#give a table True false dataframe
students.isnull()
# Out:
#     name  college  branch   cgpa  package
# 0  False    False   False  False    False
# 1  False    False   False  False    False
# 2  False    False   False  False    False
# 3   True     True    True   True     True
# 4  False     True   False  False    False
# 5   True    False   False  False    False
# 6  False    False   False  False    False
# 7   True     True   False  False    False
# 8  False     True   False  False     True
# 9   True    False    True   True     True

# %%
#notnull(series + dataframe)(opposite)
students.notnull()
# Out:
#     name  college  branch   cgpa  package
# 0   True     True    True   True     True
# 1   True     True    True   True     True
# 2   True     True    True   True     True
# 3  False    False   False  False    False
# 4   True    False    True   True     True
# 5  False     True    True   True     True
# 6   True     True    True   True     True
# 7  False    False    True   True     True
# 8   True    False    True   True    False
# 9  False     True   False  False    False

# %%
#hasnans(series)
student["cgpa"].hasna
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_8686/2094791436.py in <cell line: 0>()
#       1 #hasnans
# ----> 2 students.hasnans()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'hasnans'

# %%
#dropna(series + dataframe)
students['name'].dropna()
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 4    mrityunjay
# 6       rishabh
# 8        aditya
# Name: name, dtype: object

# %%
students.dropna()#if have nan then remove complete row
students.dropna(how='any')#If it would be all nan
# Out:
#       name college branch  cgpa  package
# 0   nitish     bit    eee  6.66      4.0
# 1    ankit     iit     it  8.25      5.0
# 2   rupesh     vit    cse  6.41      6.0
# 6  rishabh    ssit    civ  7.40      8.0

# %%
#fillna(series + dataframe)
students['name'].fillna('unknown').isnull()
students['name'].fillna(method='bfill')
# Out:
# /tmp/ipykernel_8686/162439948.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   students['name'].fillna(method='bfill')
# 0        nitish
# 1         ankit
# 2        rupesh
# 3    mrityunjay
# 4    mrityunjay
# 5       rishabh
# 6       rishabh
# 7        aditya
# 8        aditya
# 9           NaN
# Name: name, dtype: object

# %%
#drop_duplicated
marks_series.drop_duplicates()
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
virat_delhi_last = (
    ipl[
        (ipl["City"] == "Delhi") &
        (
            ipl["Team1Players"].str.contains("V Kohli", na=False) |
            ipl["Team2Players"].str.contains("V Kohli", na=False)
        )
    ]
    .sort_values(["Date", "ID"])
    .drop_duplicates(subset=["City"], keep="last")
)

virat_delhi_last[["Season", "Date", "MatchNumber", "Team1", "Team2", "WinningTeam", "Player_of_Match"]]
# Out:
#     Season        Date MatchNumber           Team1  \
# 208   2019  2019-04-28          46  Delhi Capitals
#
#                            Team2     WinningTeam Player_of_Match
# 208  Royal Challengers Bangalore  Delhi Capitals        S Dhawan
